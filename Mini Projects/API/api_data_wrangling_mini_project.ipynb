# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = '4jfZGD33JFPc9fq5NpGH'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
r = requests.get('https://www.quandl.com/api/v3/datasets/WIKI/FB/data.json?api_key=',API_KEY)
r_json = json.dumps(r.json(), sort_keys=True, indent=4)
print(r_json)
r_dict = r.json()
# r_dict["dataset_data"]["data"][0]
# Out:
# {
#     "dataset_data": {
#         "collapse": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Close",
#             "Volume",
#             "Ex-Dividend",
#             "Split Ratio",
#             "Adj. Open",
#             "Adj. High",
#             "Adj. Low",
#             "Adj. Close",
#             "Adj. Volume"
#         ],
#         "data": [
#             [
#                 "2018-03-27",
#                 156.31,
#                 162.85,
#                 150.75,
#                 152.19,
#                 76787884.0,
#                 0.0,
#                 1.0,
#                 156.31,
#                 162.85,
#                 150.75,
#                 152.19,
#                 76787884.0
#             ],
#             [
#                 "2018-03-26",
#                 160.82,
#                 161.1,
#                 149.02,
# ...

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
r = requests.get('https://www.quandl.com/api/v3/datasets/FSE/AFX_X?start_date=2017-01-01&end_date=2017-12-31&api_key=',API_KEY)

print(json.dumps(r.json(), sort_keys=True, indent=4))
# Out:
# {
#     "dataset": {
#         "collapse": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Close",
#             "Change",
#             "Traded Volume",
#             "Turnover",
#             "Last Price of the Day",
#             "Daily Traded Units",
#             "Daily Turnover"
#         ],
#         "data": [
#             [
#                 "2017-12-29",
#                 51.76,
#                 51.94,
#                 51.45,
#                 51.76,
#                 null,
#                 34640.0,
#                 1792304.0,
#                 null,
#                 null,
#                 null
#             ],
#             [
#                 "2017-12-28",
#                 51.65,
#                 51.82,
#                 51.43,
#                 51.6,
#                 null,
#                 40660.0,
#                 2099024.0,
# ...

# %%
#2. Convert the returned JSON object into a Python dictionary.
r = r.json()
print(r)
# Out:
# {'dataset': {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (AFX) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2019-06-17T22:30:14.053Z', 'newest_available_date': '2019-06-17', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'data': [['2017-12-29', 51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None], ['2017-12-28', 51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None], ['2017-12-27', 51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None], ['2
# ...

# %%
#3. Calculate what the highest and lowest opening prices were for the stock in this period.
opening_prices = []

for x in r["dataset"]["data"]:
    if x[1] is None:
        continue
    opening_prices.append(x[1])

max_opening_prices = max(opening_prices)
min_opening_prices = min(opening_prices)
    
print("2017 AFX_X Opening Price Max: ", max_opening_prices)
print("2017 AFX_X Opening Price Min: ", min_opening_prices)
# Out:
# 2017 AFX_X Opening Price Max:  53.11
# 2017 AFX_X Opening Price Min:  34.0

# %%
#4. What was the largest change in any one day (based on High and Low price)?
day_variance = []

for x in r["dataset"]["data"]:
    if x[2] is None or x[3] is None:
        continue
    difference = abs(x[2]-x[3])
    day_variance.append(difference)
    
max_day_variance = max(day_variance)
print("2017 AFX_X Max Day Variance: ", max_day_variance)
# Out:
# 2017 AFX_X Max Day Variance:  2.8100000000000023

# %%
#5. What was the largest change between any two days (based on Closing Price)?
day_to_day_var = []
previous_close_value = None

for x in r["dataset"]["data"]:
    if previous_close_value is None:
        previous_close_value = x[4]
        continue
    day_diff = abs(x[4]-previous_close_value)
    day_to_day_var.append(day_diff)
    previous_close_value = x[4]

max_diff = max(day_to_day_var)
print("2017 AFX_X Max Day-to-Day Close Price Variance: ", max_diff)
# Out:
# 2017 AFX_X Max Day-to-Day Close Price Variance:  2.559999999999995

# %%
#6. What was the average daily trading volume during this year?
daily_vol = []

for x in r["dataset"]["data"]:
    if x[6] is None:
        continue
    daily_vol.append(x[6])
    
avg_volume = sum(daily_vol)/len(daily_vol)
print("2017 AFX_X Average Traded Volume: ", avg_volume)
# Out:
# 2017 AFX_X Average Traded Volume:  89124.33725490196

# %%
#7. (Optional) What was the median trading volume during this year. 
#(Note: you may need to implement your own function for calculating the median.)
import math

def median_volume(somelist):
    somelist.sort()
    list_len = len(somelist)
    if list_len % 2 == 0:
        num1 = somelist[list_len/2]
        num2 = somelist[(list_len/2)+1]
        med = (num1+num2)/2
        return med
    else:
        med = somelist[math.ceil(list_len/2)]
        return med

my_median = median_volume(daily_vol)
print("Median: ", my_median)
# Out:
# Median:  76600.0
